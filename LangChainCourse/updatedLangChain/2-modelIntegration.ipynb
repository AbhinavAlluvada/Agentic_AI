# %% [markdown]
# #### Model Integration - 02

# %%
import os
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

OPENROUTER = os.getenv("OPENROUTER_API_KEY")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model = "openrouter/free",
    base_url = "https://openrouter.ai/api/v1",
    api_key = os.getenv("OPENROUTER_API_KEY")
)

response = llm.invoke("Hey What's up!")
response.content
# Out:
# "Hey! I'm doing well, thank you for asking. How can I help you today?"

# %%
ans = llm.invoke("Write me a 100 words essay on Volcanoes")
ans.content
# Out:
# 'Volcanoes are openings in the Earth’s crust that allow molten rock, ash, and gases to escape from below the surface. They form where tectonic plates diverge or converge, and at hotspots. When pressure builds, eruptions can be gentle or explosive, shaping landscapes and affecting climate. Volcanic soil is fertile, supporting agriculture, but eruptions threaten lives and property. Historically, volcanoes like Mount Vesuvius and Krakatoa changed human history. Today, scientists monitor them to predict activity, reducing risks. Volcanoes remind us of the planet’s dynamic power, linking the deep interior with the surface environment. Despite their danger, they inspire awe and study.'

# %%
for chunk in llm.stream("Write me a 100 words para on kittens"):
    print(chunk.text,end = " ",flush = True)
# Out:
#
#  Kit tens  are  young  cats ,  typically  under  two  years  old ,  known  for  their  playful  energy  and curious nature .  With  large  eyes ,  tiny  p aws ,  and  soft  fur ,  they  explore  the  world  with  bound less  enthusiasm ,  chasing  toys  and  climbing  surfaces .  Dependent  on  their  mothers  initially ,  they  thrive  with  love ,  proper  nutrition ,  and  a  safe  environment .  Their  ant ics — p ouncing ,  p ouncing ,  and  pur ring — br ing  joy  to  households .  Social ized  early ,  they  grow  into  confident ,  loyal  companions ,  forming  deep  bonds  with  humans  and  pets  alike .  Adopting  a  kit ten  means  embracing  endless  entertainment  and  heart war ming  moments .

# %%
responses = llm.batch([
    "what is tallest peak!",
    "how do airplanes fly?",
    "what is quantum computing?"
],
config)

for r in responses:
    print(r.content)
# Out:
# The tallest peak in the world is **Mount Everest**, located in the Himalayas on the border between **Nepal** and **China (Tibet)**. Its elevation is approximately **8,848 meters (29,029 feet)** above sea level, as confirmed by the most recent official measurements from both countries in 2020.
#
# Everest is part of the Mahalangur Himal sub-range of the broader Himalayas and is a iconic and challenging destination for climbers worldwide.
#
# Airplanes fly by generating lift to overcome their weight, using thrust to overcome drag, and controlling movement through control surfaces and engines. Here's a breakdown of the key principles and components involved:
#
# ---
#
# ### **1. Four Forces of Flight**
#    - **Lift**: An upward force created by air moving over the wings, opposing gravity (weight).
#    - **Thrust**: Forward force generated by the engines to move the airplane.
#    - **Drag**: Resistance caused by air opposing the aircraft's motion.
#    - **Weight**: The force of gravity pulling the plane downward.
#
# For flight to occur, **lift must equal or exceed weight**, and **thrust must exceed drag**.
#
# ---
#
# ### **2. Generating Lift**
#    - **Bernoulli's Principle**: Air flows faster over the curved upper surface of the wing than the flatter lower surface, creating lower pressure above the wing and higher pressure below. This pressure difference generates lift.
#    - **Angle of Attack**: The wing's tilt relative to the airflow. Adjusting this angle increases lift but also drag. Too steep an angle causes a stall.
#    - **Wing Shape**: Airfoil profiles are designed to optimize lift and minimize drag.
#
# ---
#
# ### **3. Thrust vs. Drag**
#    - **Engines**: Provide thrust to accelerate the plane forward.
#      - **Jet Engines**: Use high-speed exhaust gases (via compressors, combustion chambers, and turbines) to generate thrust.
#      - **Turbofans**: Most common in commercial aircraft; a fan at the front increases airflow through the engine, creating additional thrust efficiently (70% of thrust comes from the fan, not just the exhaust).
#    - **Drag Reduction**: Wingly/streamlined designs, retractable landing gear, and flaps (retracted during flight) minimize drag.
#
# ---
#
# ### **4. Control Surfaces**
#    - **Ailerons**: On wings; roll the aircraft (bank left/right).
#    - **Elevators**: On the tail; pitch up/down.
#    - **Rudder**: On the vertical stabilizer; yaw left/right.
#    - **Flaps**: Extend downward on wings to increase lift during takeoff/landing (also increase drag).
#
# ---
#
# ### **5. Takeoff and Landing**
#    - **Takeoff**: The plane accelerates on the runway until thrust overcomes drag, generating enough lift to become airborne.
#    - **Landing**: Thrust is reduced, and flaps extend to slow the plane safely. Reverse thrust (engines redirecting exhaust backward) aids deceleration.
#
# ---
#
# ### **6. Stability and Steering**
#    - **Aerodynamic Stability**: The fuselage, wings, and tail are designed to maintain balance in pitch, roll, and yaw.
#    - **Aircraft Systems**: Modern planes use autopilot and computerized systems (e.g., fly-by-wire) to assist pilots in controlling these forces precisely.
#
# ---
#
# ### **7. Altitude and Maneuvering**
#    - **Climb/Descent**: Pilots adjust pitch (nose up/down) and thrust to control altitude.
#    - **Maneuvering**: Control surfaces (ailerons, rudder) enable turns and direction changes.
#
# ---
#
# ### **Why Planes Stay Airborne**
#    - **Continuous Lift**: As long as wings move through air (generated by engines), lift persists, even if the plane moves at an angle.
#    - **Engine Power**: Maintains speed to generate sufficient lift, even after takeoff.
#
# ---
#
# ### **Key Design Features**
#    - **Wing Structure**: Lightweight yet strong to support lift.
#    - **Aileron Position (Up/Down)**: Depending on the aircraft model.
#
# ---
#
# ### **KeyEngine System**
#    - **Term “Aileron” refers to Control Surfaces, Not Engines**:
#      - For glassfiber design: Aileron as a ControlSurface mentioning the material’s lightweight and durability.
#      - For the engine system: Turboprop or Ronwill33-janine-aile-TarCho forgoing.
#      - Ailerweight TAI Journey by ecotwingição4901 could relate to lightweight design or environmental applications, but engines? Would need more context.
#
# ---
#
# ### **Example Aircraft:**
#    - A Boeing 747 uses high-bypass turbofan engines for efficient long-haul travel, with the wings and control surfaces managing lift and stability.
#    - A Cessna 172 uses a piston engine, with simpler controls suited for smaller missions.
#
# ---
#
# ### **Summary of Forces**
# ```
# Lift > Weight = Flight
# Thrust > Drag = Forward Motion
# ```
#
# By balancing these forces, pilots can take off, land, and navigate safely through the skies.
#
# **Quantum computing** is a new kind of computation that leverages the principles of quantum mechanics—the physics that governs the behavior of particles at the atomic and sub‑atomic scale. Instead of using classical bits (0s and 1s) as the basic units of information, quantum computers use **quantum bits**, or **qubits**, which can exist in a superposition of both 0 and 1 simultaneously.
#
# ### Key Concepts
#
# | Concept | Classical Analogy | What It Means in Quantum Computing |
# |---------|-------------------|-------------------------------------|
# | **Qubit** | A classical bit that is either 0 **or** 1 | A quantum system that can be in a linear combination α|0⟩ + β|1⟩, where α and β are complex numbers (amplitudes) and |α|² + |β|² = 1. The qubit can represent both states at once until measured. |
# | **Superposition** | A light switch that is either off or on | A qubit can occupy many possible states simultaneously, giving a computational space that grows exponentially: *n* qubits can represent 2ⁿ different classical states at the same time. |
# | **Entanglement** | Two bits that are perfectly correlated, but each still independent | Qubits become linked such that the state of one instantly determines the state of the other, no matter the distance. Entanglement enables correlations that are stronger than any classical correlation. |
# | **Interference** | Adding waves to amplify or cancel each other | Quantum algorithms manipulate the amplitudes of different paths so that “good” answers constructively interfere and “bad” answers destructively cancel out. |
# | **Measurement** | Reading a bit to see its value | When a qubit is measured, it collapses to a definite classical state (0 or 1) according to the probabilities given by its amplitudes. This step extracts the final result. |
#
# ### How It Works (in a nutshell)
#
# 1. **Initialization** – Prepare an array of qubits, typically starting in a known state (e.g., all |0⟩).
# 2. **Quantum Gates** – Apply a sequence of *quantum gates* (unitary operations) that rotate, flip, or entangle the qubits. These are the analog of logical gates in classical circuits but operate on superpositions and entangled states.
# 3. **Computation** – Let the superposition propagate through the circuit; interference shapes the amplitudes so that the desired answer’s amplitude becomes large.
# 4. **Measurement** – Collapse the qubits to classical bits. The measurement yields the output, which, with high probability, reflects the solution to the problem.
#
# ### Where Quantum Advantage Appears
#
# - **Factoring large integers** (Shor’s algorithm) – threatens current public‑key cryptography.
# - **Searching unsorted databases** (Grover’s algorithm) – offers a quadratic speed‑up.
# - **Simulating quantum systems** (chemistry, materials science) – natural fit for quantum hardware.
# - **Optimization & sampling** (variational algorithms, quantum annealing) – used for logistics, finance, ML.
#
# These problems can be solved exponentially or polynomially faster on a sufficiently large, error‑corrected quantum computer compared with the best known classical algorithms.
#
# ### Practical Status Today
#
# - **Hardware** – Companies like IBM, Google, Rigetti, IonQ, and many startups have built devices with tens to a few hundred noisy qubits (often called NISQ – Noisy Intermediate‑Scale Quantum).
# - **Error correction** – Full fault‑tolerant quantum computing requires error‑correcting codes that need many physical qubits per logical qubit (estimates >1,000–10,000 physical qubits per logical qubit, depending on error rates). This is still an active research frontier.
# - **Applications** – Early demonstrations show promise for specific niche tasks (e.g., chemistry simulations of small molecules, random circuit sampling), but practical, large‑scale impact is still years to decades away.
#
# ### A Simple Example: The Hadamard Gate
#
# The most common “quantum coin flip” is the **Hadamard gate**:
#
# \[
# H|0\rangle = \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)
# \]
#
# Applying \(H\) to a single qubit creates an equal superposition of 0 and 1. If you measure it, you’ll see 0 or 1 each with 50 % probability. When you apply \(H\) to many qubits, you generate a superposition of all possible \(2^n\) bit‑strings. Certain later gates interfere so that only the “correct” bit‑strings survive with high probability, which you then measure.
#
# ### Bottom Line
#
# Quantum computing redefines how information can be stored and processed by exploiting wave‑like superposition, spooky entanglement, and wave interference. While still in its infancy, it promises to solve certain classes of problems far more efficiently than any classical computer ever could—though turning this promise into widespread, reliable technology remains a formidable engineering and scientific challenge.
